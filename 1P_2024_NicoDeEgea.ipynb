# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.0.0-py3-none-any.whl.metadata (16 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.13.2-py3-none-any.whl.metadata (7.4 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.8.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (24.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.34)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.5)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.2)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.5-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (3.0.3)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.5)
# Downloading optuna-4.0.0-py3-none-any.whl (362 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.8/362.8 kB 15.9 MB/s eta 0:00:00
# Downloading alembic-1.13.2-py3-none-any.whl (232 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.0/233.0 kB 17.7 MB/s eta 0:00:00
# Downloading colorlog-6.8.2-py3-none-any.whl (11 kB)
# Downloading Mako-1.3.5-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 6.1 MB/s eta 0:00:00
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.5 alembic-1.13.2 colorlog-6.8.2 optuna-4.0.0

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import optuna
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
SEED=1234

# %%
# Funcion para graficar las curvas de entrenamiento y de validacion
import matplotlib.pyplot as plt
def visualize_loss(history, title):
    loss = history.history["loss"]
    val_loss = history.history["val_loss"]
    epochs = range(len(loss))
    plt.figure()
    plt.plot(epochs, loss, "b", label="Training loss")
    plt.plot(epochs, val_loss, "r", label="Validation loss")
    plt.title(title)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.show()

# %%
# Cargar el conjunto de datos
datos = pd.read_csv('/content/drive/MyDrive/Inteligencia Artificial/Temp_Asu20092021.csv')

# %%
# Convertir la columna 'Fecha' al tipo datetime y establecerla como índice
datos['Fecha'] = pd.to_datetime(datos['Fecha'])
datos.set_index('Fecha', inplace=True)

# %%
# Filtrar datos a partir de 2019
datos = datos[datos.index.year >= 2019]

# %%
# Eliminar filas con valores faltantes
datos.dropna(inplace=True)

# %%
# Calcular los percentiles 95, 50 (mediana) y 5 para cada día
percentiles_diarios = datos.resample('D')['Temperatura'].agg([lambda x: np.percentile(x, 95),
                                                              lambda x: np.percentile(x, 50),
                                                              lambda x: np.percentile(x, 5)])
percentiles_diarios.columns = ['Percentil_95', 'Mediana', 'Percentil_5']

# %%
# Desplazar para obtener los percentiles del siguiente día como variables objetivo
percentiles_diarios['Percentil_95_siguiente_dia'] = percentiles_diarios['Percentil_95'].shift(-1)
percentiles_diarios['Mediana_siguiente_dia'] = percentiles_diarios['Mediana'].shift(-1)
percentiles_diarios['Percentil_5_siguiente_dia'] = percentiles_diarios['Percentil_5'].shift(-1)

# %%
# Eliminar filas con valores faltantes
percentiles_diarios.dropna(inplace=True)

# %%
# Seleccionar características (por ejemplo,buscar variables adicionales)
X = percentiles_diarios[['Percentil_95','Mediana','Percentil_5']].values
y = percentiles_diarios[['Percentil_95_siguiente_dia','Mediana_siguiente_dia','Percentil_5_siguiente_dia']].values

# %%
# Escalar las características
scaler_X = StandardScaler()
X_escalado = scaler_X.fit_transform(X)

# %%
# Dividir datos en conjuntos de entrenamiento y validación
X_entrenamiento, X_validacion, y_entrenamiento, y_validacion = train_test_split(X_escalado, y, test_size=0.2, random_state=SEED, shuffle=False)

# %%
# Definir función objetivo para Optuna
def objetivo(trial):
    num_capas = 1
    tf.keras.utils.set_random_seed(SEED)

    num_capas = 1
    num_unidades = trial.suggest_categorical('num_unidades', [16, 32, 64])


    # Definir la arquitectura del modelo
    modelo = Sequential()
    modelo.add(Dense(num_unidades, activation='relu', input_shape=(X_entrenamiento.shape[1],)))
    for _ in range(num_capas - 1):
        modelo.add(Dense(num_unidades, activation='relu'))

    # Capa de salida para predecir los 3 percentiles (95, 50, 5)
    modelo.add(Dense(3, activation='linear'))

    # Compilar el modelo
    modelo.compile(optimizer=Adam(),
                   loss='mse',  # Para regresión, se usa 'mean squared error'
                   metrics=['mae'])  # Mean Absolute Error (MAE) para evaluación

    # Entrenar el modelo
    modelo.fit(X_entrenamiento, y_entrenamiento, validation_data=(X_validacion, y_validacion), epochs=30, batch_size=256, verbose=0, shuffle=False)

    # Evaluar el modelo en el conjunto de validación
    _, val_mae = modelo.evaluate(X_validacion, y_validacion, verbose=0)

    return val_mae

# %%
# Realizar la optimización de hiperparámetros usando Optuna
estudio = optuna.create_study(direction='minimize')  # Minimizamos el MAE en lugar de maximizar
estudio.optimize(objetivo, n_trials=100)
# Out:
# [I 2024-09-11 21:17:39,193] A new study created in memory with name: no-name-209e6328-3208-461a-87a2-9a32cfc9419f
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# [I 2024-09-11 21:17:42,369] Trial 0 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:17:46,420] Trial 1 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:17:49,070] Trial 2 finished with value: 21.93014144897461 and parameters: {'num_unidades': 16}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:17:51,872] Trial 3 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:17:54,564] Trial 4 finished with value: 21.93014144897461 and parameters: {'num_unidades': 16}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:17:58,920] Trial 5 finished with value: 21.93014144897461 and parameters: {'num_unidades': 16}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:18:02,230] Trial 6 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:18:05,168] Trial 7 finished with value: 21.118589401245117 and parameters: {'num_unidades': 32}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:18:07,964] Trial 8 finished with value: 21.93014144897461 and parameters: {'num_unidades': 16}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:18:12,389] Trial 9 finished with value: 21.93014144897461 and parameters: {'num_unidades': 16}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:18:15,093] Trial 10 finished with value: 21.118589401245117 and parameters: {'num_unidades': 32}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:18:17,879] Trial 11 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:18:20,688] Trial 12 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:18:25,280] Trial 13 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:18:28,013] Trial 14 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:18:30,942] Trial 15 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:18:33,793] Trial 16 finished with value: 21.118589401245117 and parameters: {'num_unidades': 32}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:18:38,060] Trial 17 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:18:41,222] Trial 18 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:18:44,012] Trial 19 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:18:47,474] Trial 20 finished with value: 21.118589401245117 and parameters: {'num_unidades': 32}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:18:52,020] Trial 21 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:18:54,739] Trial 22 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:18:57,592] Trial 23 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:19:00,444] Trial 24 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:19:04,647] Trial 25 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:19:07,684] Trial 26 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:19:10,404] Trial 27 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:19:13,079] Trial 28 finished with value: 21.118589401245117 and parameters: {'num_unidades': 32}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:19:16,761] Trial 29 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:19:20,184] Trial 30 finished with value: 21.93014144897461 and parameters: {'num_unidades': 16}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:19:22,988] Trial 31 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:19:25,848] Trial 32 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:19:28,732] Trial 33 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:19:32,935] Trial 34 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:19:35,691] Trial 35 finished with value: 21.93014144897461 and parameters: {'num_unidades': 16}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:19:39,685] Trial 36 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:19:42,523] Trial 37 finished with value: 21.93014144897461 and parameters: {'num_unidades': 16}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:19:46,644] Trial 38 finished with value: 21.118589401245117 and parameters: {'num_unidades': 32}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:19:49,411] Trial 39 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:19:52,031] Trial 40 finished with value: 21.93014144897461 and parameters: {'num_unidades': 16}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:19:54,778] Trial 41 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:19:59,323] Trial 42 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:20:03,534] Trial 43 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:20:06,212] Trial 44 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:20:08,992] Trial 45 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:20:13,372] Trial 46 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:20:16,400] Trial 47 finished with value: 21.118589401245117 and parameters: {'num_unidades': 32}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:20:19,257] Trial 48 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:20:22,107] Trial 49 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:20:25,914] Trial 50 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:20:29,460] Trial 51 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:20:32,290] Trial 52 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:20:35,041] Trial 53 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:20:38,186] Trial 54 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:20:43,131] Trial 55 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:20:47,346] Trial 56 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:20:50,172] Trial 57 finished with value: 21.118589401245117 and parameters: {'num_unidades': 32}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:20:53,727] Trial 58 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:20:57,168] Trial 59 finished with value: 21.93014144897461 and parameters: {'num_unidades': 16}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:21:00,018] Trial 60 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:21:02,828] Trial 61 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:21:05,772] Trial 62 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:21:10,179] Trial 63 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:21:13,103] Trial 64 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:21:15,833] Trial 65 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:21:18,608] Trial 66 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:21:23,234] Trial 67 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:21:25,980] Trial 68 finished with value: 21.118589401245117 and parameters: {'num_unidades': 32}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:21:28,787] Trial 69 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:21:31,521] Trial 70 finished with value: 21.93014144897461 and parameters: {'num_unidades': 16}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:21:36,061] Trial 71 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:21:38,962] Trial 72 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:21:41,827] Trial 73 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:21:44,551] Trial 74 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:21:49,256] Trial 75 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:21:52,221] Trial 76 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:21:56,112] Trial 77 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:21:58,956] Trial 78 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:22:03,373] Trial 79 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:22:06,108] Trial 80 finished with value: 21.118589401245117 and parameters: {'num_unidades': 32}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:22:09,102] Trial 81 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:22:11,900] Trial 82 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:22:16,404] Trial 83 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:22:19,257] Trial 84 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:22:22,037] Trial 85 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:22:24,752] Trial 86 finished with value: 21.93014144897461 and parameters: {'num_unidades': 16}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:22:29,322] Trial 87 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:22:32,154] Trial 88 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:22:34,951] Trial 89 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:22:37,923] Trial 90 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:22:42,546] Trial 91 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:22:45,224] Trial 92 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:22:47,944] Trial 93 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:22:50,692] Trial 94 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:22:54,886] Trial 95 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:22:58,074] Trial 96 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:23:01,524] Trial 97 finished with value: 21.118589401245117 and parameters: {'num_unidades': 32}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:23:04,385] Trial 98 finished with value: 20.4274845123291 and parameters: {'num_unidades': 64}. Best is trial 0 with value: 20.4274845123291.
# [I 2024-09-11 21:23:08,199] Trial 99 finished with value: 21.93014144897461 and parameters: {'num_unidades': 16}. Best is trial 0 with value: 20.4274845123291.

# %%
# Obtener los mejores hiperparámetros
mejor_num_capas =  1
mejor_num_unidades = estudio.best_params['num_unidades']
print("Mejores Hiperparámetros:")
print("Número de Capas:", 1)
print("Número de Unidades:", mejor_num_unidades)
# Out:
# Mejores Hiperparámetros:
# Número de Capas: 1
# Número de Unidades: 64

# %%
# Entrenar el modelo final usando los mejores hiperparámetros
modelo_final = Sequential()
modelo_final.add(Dense(mejor_num_unidades, activation='relu', input_shape=(X_entrenamiento.shape[1],)))
for _ in range(mejor_num_capas - 1):
    modelo_final.add(Dense(mejor_num_unidades, activation='relu'))
modelo_final.add(Dense(3, activation='linear'))

modelo_final.compile(optimizer=tf.keras.optimizers.Adam(),
                     loss='mse',
                     metrics=['mae'])

# %%
# Entrenar el modelo final
history=modelo_final.fit(X_entrenamiento, y_entrenamiento, validation_data=(X_validacion, y_validacion), epochs=50, batch_size=256, verbose=1, shuffle=False)
# Out:
# Epoch 1/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 629.9698 - mae: 23.9944 - val_loss: 588.8467 - val_mae: 22.9064
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 627.0723 - mae: 23.9342 - val_loss: 586.0829 - val_mae: 22.8439
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 624.1583 - mae: 23.8735 - val_loss: 583.2867 - val_mae: 22.7806
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 621.2073 - mae: 23.8120 - val_loss: 580.4520 - val_mae: 22.7162
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 618.2095 - mae: 23.7494 - val_loss: 577.5688 - val_mae: 22.6506
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 615.1569 - mae: 23.6855 - val_loss: 574.6271 - val_mae: 22.5834
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 612.0364 - mae: 23.6200 - val_loss: 571.6180 - val_mae: 22.5145
# Epoch 8/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 608.8347 - mae: 23.5526 - val_loss: 568.5306 - val_mae: 22.4434
# Epoch 9/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 605.5415 - mae: 23.4829 - val_loss: 565.3546 - val_mae: 22.3699
# Epoch 10/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 602.1466 - mae: 23.4108 - val_loss: 562.0814 - val_mae: 22.2937
# Epoch 11/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 598.6389 - mae: 23.3359 - val_loss: 558.7012 - val_mae: 22.2146
# Epoch 12/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 595.0089 - mae: 23.2581 - val_loss: 555.2078 - val_mae: 22.1323
# Epoch 13/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 591.2490 - mae: 23.1771 - val_loss: 551.5982 - val_mae: 22.0469
# Epoch 14/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 587.3522 - mae: 23.0926 - val_loss: 547.8633 - val_mae: 21.9585
# Epoch 15/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 583.3121 - mae: 23.0048 - val_loss: 543.9937 - val_mae: 21.8667
# Epoch 16/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 579.1223 - mae: 22.9134 - val_loss: 539.9872 - val_mae: 21.7720
# Epoch 17/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 574.7773 - mae: 22.8180 - val_loss: 535.8403 - val_mae: 21.6738
# Epoch 18/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 570.2739 - mae: 22.7185 - val_loss: 531.5498 - val_mae: 21.5714
# Epoch 19/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 565.6073 - mae: 22.6147 - val_loss: 527.1123 - val_mae: 21.4648
# Epoch 20/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 560.7755 - mae: 22.5065 - val_loss: 522.5277 - val_mae: 21.3537
# Epoch 21/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 555.7775 - mae: 22.3938 - val_loss: 517.7944 - val_mae: 21.2390
# Epoch 22/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 550.6120 - mae: 22.2766 - val_loss: 512.9140 - val_mae: 21.1196
# Epoch 23/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 545.2817 - mae: 22.1550 - val_loss: 507.8875 - val_mae: 20.9956
# Epoch 24/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 539.7874 - mae: 22.0287 - val_loss: 502.7153 - val_mae: 20.8669
# Epoch 25/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 534.1322 - mae: 21.8977 - val_loss: 497.4016 - val_mae: 20.7335
# Epoch 26/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 528.3198 - mae: 21.7624 - val_loss: 491.9495 - val_mae: 20.5956
# Epoch 27/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 522.3518 - mae: 21.6224 - val_loss: 486.3651 - val_mae: 20.4540
# Epoch 28/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 516.2334 - mae: 21.4776 - val_loss: 480.6548 - val_mae: 20.3081
# Epoch 29/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 509.9695 - mae: 21.3281 - val_loss: 474.8246 - val_mae: 20.1577
# Epoch 30/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 503.5637 - mae: 21.1742 - val_loss: 468.8824 - val_mae: 20.0026
# Epoch 31/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 497.0221 - mae: 21.0163 - val_loss: 462.8327 - val_mae: 19.8430
# Epoch 32/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 490.3490 - mae: 20.8539 - val_loss: 456.6809 - val_mae: 19.6792
# Epoch 33/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 483.5493 - mae: 20.6871 - val_loss: 450.4341 - val_mae: 19.5118
# Epoch 34/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 476.6288 - mae: 20.5164 - val_loss: 444.0979 - val_mae: 19.3404
# Epoch 35/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 469.5931 - mae: 20.3412 - val_loss: 437.6778 - val_mae: 19.1645
# Epoch 36/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 462.4474 - mae: 20.1619 - val_loss: 431.1804 - val_mae: 18.9860
# Epoch 37/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 455.1974 - mae: 19.9788 - val_loss: 424.6134 - val_mae: 18.8068
# Epoch 38/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 447.8504 - mae: 19.7928 - val_loss: 417.9838 - val_mae: 18.6266
# Epoch 39/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 440.4131 - mae: 19.6032 - val_loss: 411.2989 - val_mae: 18.4470
# Epoch 40/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 432.8925 - mae: 19.4108 - val_loss: 404.5665 - val_mae: 18.2693
# Epoch 41/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 425.2984 - mae: 19.2148 - val_loss: 397.7961 - val_mae: 18.0924
# Epoch 42/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 417.6406 - mae: 19.0163 - val_loss: 390.9962 - val_mae: 17.9130
# Epoch 43/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 409.9291 - mae: 18.8152 - val_loss: 384.1733 - val_mae: 17.7332
# Epoch 44/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 402.1736 - mae: 18.6122 - val_loss: 377.3378 - val_mae: 17.5504
# Epoch 45/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 394.3833 - mae: 18.4066 - val_loss: 370.5002 - val_mae: 17.3660
# Epoch 46/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 386.5701 - mae: 18.1982 - val_loss: 363.6673 - val_mae: 17.1828
# Epoch 47/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 378.7437 - mae: 17.9874 - val_loss: 356.8463 - val_mae: 16.9995
# Epoch 48/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 370.9129 - mae: 17.7752 - val_loss: 350.0471 - val_mae: 16.8142
# Epoch 49/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 363.0888 - mae: 17.5627 - val_loss: 343.2795 - val_mae: 16.6277
# Epoch 50/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 355.2810 - mae: 17.3490 - val_loss: 336.5521 - val_mae: 16.4437

# %%
# Evaluar en conjunto de prueba
mae = modelo_final.evaluate(X_validacion, y_validacion, verbose=0)
print(f'MAE en validación: {mae}')
# Out:
# MAE en validación: [336.5521240234375, 16.443742752075195]

# %%
visualize_loss(history, "Training and Validation Loss")

# %%
# Entrenar el modelo final usando los mejores hiperparámetros
modelo_final = Sequential()
modelo_final.add(Dense(mejor_num_unidades, activation='relu', input_shape=(X_entrenamiento.shape[1],)))
for _ in range(mejor_num_capas - 1):
    modelo_final.add(Dense(mejor_num_unidades, activation='relu'))
modelo_final.add(Dense(3, activation='linear'))

modelo_final.compile(optimizer=tf.keras.optimizers.Adam(),
                     loss='mae',
                     metrics=['mse'])

# %%
# Entrenar el modelo final
history=modelo_final.fit(X_entrenamiento, y_entrenamiento, validation_data=(X_validacion, y_validacion), epochs=50, batch_size=256, verbose=1, shuffle=False)
# Out:
# Epoch 1/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 23.9832 - mse: 629.8868 - val_loss: 22.8730 - val_mse: 587.7679
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 23.9242 - mse: 627.1221 - val_loss: 22.8111 - val_mse: 585.1466
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 23.8646 - mse: 624.3372 - val_loss: 22.7481 - val_mse: 582.4857
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 23.8039 - mse: 621.5032 - val_loss: 22.6839 - val_mse: 579.7673
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 23.7419 - mse: 618.6022 - val_loss: 22.6180 - val_mse: 576.9761
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 23.6782 - mse: 615.6217 - val_loss: 22.5502 - val_mse: 574.1050
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 23.6125 - mse: 612.5515 - val_loss: 22.4802 - val_mse: 571.1456
# Epoch 8/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 23.5446 - mse: 609.3837 - val_loss: 22.4077 - val_mse: 568.0877
# Epoch 9/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 23.4743 - mse: 606.1080 - val_loss: 22.3323 - val_mse: 564.9213
# Epoch 10/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 23.4011 - mse: 602.7164 - val_loss: 22.2537 - val_mse: 561.6405
# Epoch 11/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 23.3250 - mse: 599.1980 - val_loss: 22.1719 - val_mse: 558.2379
# Epoch 12/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 23.2455 - mse: 595.5443 - val_loss: 22.0864 - val_mse: 554.7057
# Epoch 13/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 23.1626 - mse: 591.7501 - val_loss: 21.9973 - val_mse: 551.0397
# Epoch 14/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 23.0760 - mse: 587.8091 - val_loss: 21.9041 - val_mse: 547.2329
# Epoch 15/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 22.9855 - mse: 583.7124 - val_loss: 21.8072 - val_mse: 543.2771
# Epoch 16/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 22.8910 - mse: 579.4520 - val_loss: 21.7068 - val_mse: 539.1667
# Epoch 17/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 22.7923 - mse: 575.0208 - val_loss: 21.6024 - val_mse: 534.9005
# Epoch 18/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 22.6891 - mse: 570.4156 - val_loss: 21.4940 - val_mse: 530.4742
# Epoch 19/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 22.5812 - mse: 565.6344 - val_loss: 21.3809 - val_mse: 525.8843
# Epoch 20/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 22.4685 - mse: 560.6732 - val_loss: 21.2628 - val_mse: 521.1312
# Epoch 21/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 22.3509 - mse: 555.5300 - val_loss: 21.1396 - val_mse: 516.2134
# Epoch 22/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 22.2283 - mse: 550.2050 - val_loss: 21.0117 - val_mse: 511.1346
# Epoch 23/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 22.1011 - mse: 544.6992 - val_loss: 20.8799 - val_mse: 505.8962
# Epoch 24/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 21.9688 - mse: 539.0141 - val_loss: 20.7432 - val_mse: 500.4978
# Epoch 25/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 21.8313 - mse: 533.1492 - val_loss: 20.6028 - val_mse: 494.9440
# Epoch 26/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 21.6884 - mse: 527.1081 - val_loss: 20.4582 - val_mse: 489.2372
# Epoch 27/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 21.5403 - mse: 520.8924 - val_loss: 20.3095 - val_mse: 483.3839
# Epoch 28/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 21.3869 - mse: 514.5040 - val_loss: 20.1576 - val_mse: 477.3891
# Epoch 29/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 21.2282 - mse: 507.9463 - val_loss: 20.0005 - val_mse: 471.2581
# Epoch 30/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 21.0649 - mse: 501.2247 - val_loss: 19.8383 - val_mse: 465.0023
# Epoch 31/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 20.8975 - mse: 494.3458 - val_loss: 19.6714 - val_mse: 458.6259
# Epoch 32/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 20.7251 - mse: 487.3130 - val_loss: 19.5005 - val_mse: 452.1283
# Epoch 33/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 20.5476 - mse: 480.1271 - val_loss: 19.3252 - val_mse: 445.5162
# Epoch 34/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 20.3651 - mse: 472.7920 - val_loss: 19.1454 - val_mse: 438.7940
# Epoch 35/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 20.1788 - mse: 465.3139 - val_loss: 18.9626 - val_mse: 431.9767
# Epoch 36/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 19.9889 - mse: 457.7049 - val_loss: 18.7755 - val_mse: 425.0700
# Epoch 37/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 19.7957 - mse: 449.9743 - val_loss: 18.5850 - val_mse: 418.0863
# Epoch 38/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 19.5996 - mse: 442.1327 - val_loss: 18.3969 - val_mse: 411.0341
# Epoch 39/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 19.4008 - mse: 434.1852 - val_loss: 18.2096 - val_mse: 403.9188
# Epoch 40/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 19.1983 - mse: 426.1400 - val_loss: 18.0256 - val_mse: 396.7496
# Epoch 41/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 18.9923 - mse: 418.0056 - val_loss: 17.8422 - val_mse: 389.5319
# Epoch 42/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 18.7831 - mse: 409.7892 - val_loss: 17.6580 - val_mse: 382.2874
# Epoch 43/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 18.5721 - mse: 401.5090 - val_loss: 17.4741 - val_mse: 375.0146
# Epoch 44/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 18.3582 - mse: 393.1659 - val_loss: 17.2913 - val_mse: 367.7279
# Epoch 45/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 18.1424 - mse: 384.7757 - val_loss: 17.1080 - val_mse: 360.4347
# Epoch 46/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 17.9233 - mse: 376.3434 - val_loss: 16.9240 - val_mse: 353.1358
# Epoch 47/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 17.7012 - mse: 367.8715 - val_loss: 16.7370 - val_mse: 345.8437
# Epoch 48/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 17.4777 - mse: 359.3737 - val_loss: 16.5483 - val_mse: 338.5721
# Epoch 49/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 17.2520 - mse: 350.8613 - val_loss: 16.3614 - val_mse: 331.3183
# Epoch 50/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 17.0230 - mse: 342.3344 - val_loss: 16.1747 - val_mse: 324.0836

# %%
# Evaluar en conjunto de prueba
mse = modelo_final.evaluate(X_validacion, y_validacion, verbose=0)
print(f'MSE en validación: {mse}')
# Out:
# MSE en validación: [16.17474937438965, 324.0836181640625]

# %%
visualize_loss(history, "Training and Validation Loss")
